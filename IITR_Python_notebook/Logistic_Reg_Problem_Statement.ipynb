# %% [markdown]
# # Heart Disease Prediction
# ### Topic: Logistic Regression
#
# ---
#
# **Background:**
#
# You have been given a cleaned dataset `heart.csv` containing health records of patients.
# Your job is to build a Logistic Regression model, evaluate its performance,
# and visualize the results using a Confusion Matrix and ROC Curve.
#
# ---

# %% [markdown]
# ## Step 0 — Import Libraries

# %%
import pandas as pd                        # For loading the dataset
import matplotlib.pyplot as plt            # For plotting
import seaborn as sns                      # For confusion matrix heatmap
import numpy as np                         # For numerical operations

from sklearn.model_selection import train_test_split   # To split data
from sklearn.linear_model import LogisticRegression    # Our model
from sklearn.metrics import (
    accuracy_score,     # Overall accuracy
    confusion_matrix,   # True/False Positives and Negatives
    roc_curve,          # ROC curve points
    roc_auc_score       # Area Under the Curve score
)
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings('ignore', category=ConvergenceWarning)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ---
# ## Question 1 — Load the Dataset
#
# Load the provided `heart.csv` file and:
# - Display the first 5 rows
# - Separate features `X` (all columns except `target`) and target `y` (`target` column)

# %%
# Write your code here

# %% [markdown]
# ---
# ## Question 2 — Train / Test Split
#
# Split the data into:
# - **80%** for training
# - **20%** for testing

# %%
# Write your code here

# %% [markdown]
# ### Solution — Question 2

# %%
# Split data into training and test sets
# random_state=42 ensures we get the same split every time
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,      # 20% for testing
    random_state=42     # Reproducibility
)

print("Training samples :", X_train.shape[0])
print("Test samples     :", X_test.shape[0])

# %% [markdown]
# ---
# ## Question 3 — Train the Model
#
# Train a `LogisticRegression` model on the training data.

# %%
# Write your code here

# %% [markdown]
# ---
# ## Question 4 — Accuracy Score
#
# Use the trained model to make predictions on the **test set** and print the accuracy.

# %%
# Write your code here

# %% [markdown]
# ---
# ## Question 5 — Confusion Matrix
#
# Plot the confusion matrix to see how many patients were correctly and incorrectly classified.

# %%
# Write your code here

# %% [markdown]
# ---
# ## Question 6 — ROC Curve
#
# Plot the ROC Curve and display the AUC score.
#
# > The ROC curve shows the tradeoff between catching real patients (Recall)
# > and raising false alarms (False Positive Rate) at different thresholds.
# > AUC closer to 1.0 means a better model.

# %%
# Write your code here
